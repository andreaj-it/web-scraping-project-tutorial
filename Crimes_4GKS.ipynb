# %% [markdown]
# <a href="https://colab.research.google.com/github/andreaj-it/web-scraping-project-tutorial/blob/main/Crimes_4GKS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1. Read the dataset
url = 'https://datos.cdmx.gob.mx/dataset/12d22477-bcf1-49ee-92aa-16a0d0a5817c/' + \
      'resource/3f308147-b1fc-49a9-92b7-e74f3f79aa9c/download/' + \
      'carpetas-de-investigacion-pgj-cdmx.csv'
df = pd.read_csv(url)

# %%
# 2. View the basic data structure and dimensions 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 808871 entries, 0 to 808870
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    808871 non-null  int64
#  1   ao_hechos             808673 non-null  float64
#  2   mes_hechos            808673 non-null  object
#  3   fecha_hechos          808673 non-null  object
#  4   delito                808871 non-null  object
#  5   categoria_delito      808871 non-null  object
#  6   fiscalia              808871 non-null  object
#  7   agencia               808871 non-null  object
#  8   unidad_investigacion  808646 non-null  object
#  9   colonia_hechos        776781 non-null  object
#  10  alcaldia_hechos       807860 non-null  object
#  11  fecha_inicio          808871 non-null  object
#  12  mes_inicio            808871 non-null  object
#  13  ao_inicio             808871 non-null  int64
#  14  calle_hechos          806467 non-null  object
#  15  calle_hechos2         328009 non-null  object
#  16  longitud              777536 non-null  float64
#  17  latitud               777536 non-null  float64
#  18  geopoint              777536 non-null  object
# dtypes: float64(3), int64(2), object(14)
# memory usage: 117.3+ MB

# %%
# 3. Display some observations
df.sample(10)
# Out:
#             id  ao_hechos mes_hechos         fecha_hechos  \
# 165483  165483     2018.0    Octubre  2018-10-11 09:30:00
# 585020  585020     2016.0      Enero  2016-01-04 08:30:00
# 197675  197675     2018.0  Noviembre  2018-11-28 21:00:00
# 658647  658647     2018.0      Junio  2018-06-18 12:00:00
# 462867  462867     2017.0      Junio  2017-06-15 07:00:00
# 171939  171939     2018.0      Marzo  2018-03-16 09:00:00
# 408104  408104     2019.0      Junio  2019-06-27 14:30:00
# 678296  678296     2019.0      Marzo  2019-03-25 03:20:00
# 527719  527719     2017.0  Noviembre  2017-11-13 11:30:00
# 291883  291883     2016.0      Julio  2016-07-07 09:00:00
#
#                                                    delito  \
# 165483  FALSIFICACION DE TITULOS AL PORTADOR Y DOCUMEN...
# 585020        ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO
# 197675           LESIONES CULPOSAS POR TRANSITO VEHICULAR
# 658647                                           AMENAZAS
# 462867                  ROBO DE MOTOCICLETA CON VIOLENCIA
# 171939                        RESPONSABILIDAD PROFESIONAL
# 408104     ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
# 678296                       ROBO A NEGOCIO SIN VIOLENCIA
# 527719                                 DENUNCIA DE HECHOS
# 291883                                    MALTRATO ANIMAL
#
#                                          categoria_delito  \
# 165483                             DELITO DE BAJO IMPACTO
# 585020                             DELITO DE BAJO IMPACTO
# 197675                             DELITO DE BAJO IMPACTO
# 658647                             DELITO DE BAJO IMPACTO
# 462867               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA
# 171939                             DELITO DE BAJO IMPACTO
# 408104  ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIO...
# 678296                             DELITO DE BAJO IMPACTO
# 527719                                 HECHO NO DELICTIVO
# 291883                             DELITO DE BAJO IMPACTO
#
#                                                  fiscalia agencia  \
# 165483                    INVESTIGACIÓN EN MIGUEL HIDALGO    MH-4
# 585020                    INVESTIGACIÓN EN ÁLVARO OBREGÓN    AO-1
# 197675                        INVESTIGACIÓN EN XOCHIMILCO    XO-2
# 658647               INVESTIGACIÓN EN VENUSTIANO CARRANZA    VC-1
# 462867                        INVESTIGACIÓN EN IZTAPALAPA   IZP-5
# 171939  INVESTIGACIÓN EN DELITOS AMBIENTALES Y EN MATE...       A
# 408104               INVESTIGACIÓN EN VENUSTIANO CARRANZA    VC-3
# 678296                     INVESTIGACIÓN EN BENITO JUÁREZ    BJ-2
# 527719                          INVESTIGACIÓN EN COYOACÁN   COY-1
# 291883  INVESTIGACIÓN EN DELITOS AMBIENTALES Y EN MATE...       A
#
#         unidad_investigacion             colonia_hechos      alcaldia_hechos  \
# 165483                UI-3SD        COPILCO UNIVERSIDAD             COYOACAN
# 585020                UI-3SD     SAN PEDRO DE LOS PINOS       ALVARO OBREGON
# 197675                UI-3CD      SANTA CRUZ XOCHITEPEC           XOCHIMILCO
# 658647                UI-1SD                    MORELOS  VENUSTIANO CARRANZA
# 462867                UI-3SD              LA VALENCIANA           IZTAPALAPA
# 171939  1 CON DETENIDO 1 C/D  SANTA MARTHA ACATITLA SUR           IZTAPALAPA
# 408104                UI-1SD   GENERAL IGNACIO ZARAGOZA  VENUSTIANO CARRANZA
# 678296                UI-2CD                   NARVARTE        BENITO JUAREZ
# 527719                UI-1CD       CAMPESTRE CHURUBUSCO             COYOACAN
# 291883  2 CON DETENIDO 2 C/D     SAN MIGUEL CHAPULTEPEC       MIGUEL HIDALGO
#
#                fecha_inicio mes_inicio  ao_inicio  \
# 165483  2018-10-11 17:46:44    Octubre       2018
# 585020  2016-01-04 16:38:38      Enero       2016
# 197675  2018-11-28 22:58:22  Noviembre       2018
# 658647  2018-06-20 13:57:19      Junio       2018
# 462867  2017-06-15 21:39:22      Junio       2017
# 171939  2018-12-20 19:22:29  Diciembre       2018
# 408104  2019-06-27 11:36:39      Junio       2019
# 678296  2019-03-25 04:09:37      Marzo       2019
# 527719  2017-11-13 19:53:57  Noviembre       2017
# 291883  2016-07-13 11:15:44      Julio       2016
#
#                            calle_hechos          calle_hechos2   longitud  \
# 165483                  AVENIDA COPILCO                    NaN -99.180930
# 585020                         CALLE 10                    NaN -99.195097
# 197675                        GARDENIAS                    NaN -99.126046
# 658647                       JARDINEROS                    NaN -99.118935
# 462867          GENERAL FRANCISCO LEYVA  GENERAL JUAN ENRIQUEZ -99.038299
# 171939  FEDERICO GONZALEZ GARZA FRACC B                    NaN -99.019574
# 408104                         CALLE 27                    NaN -99.093826
# 678296                        TEPOZTECO                    NaN -99.151910
# 527719                   CALZ. TAXQUEÑA     CERRO DEL SOMBRERO -99.140960
# 291883                        CHIVATITO                    NaN -99.193927
#
#           latitud                      geopoint
# 165483  19.336252  19.3362521913,-99.1809297855
# 585020  19.387203      19.3872031998,-99.195097
# 197675  19.253607  19.2536071867,-99.1260457623
# 658647  19.442206  19.4422057902,-99.1189345146
# 462867  19.389546  19.3895464254,-99.0382989035
# 171939  19.365994     19.3659938998,-99.0195741
# 408104  19.412245  19.4122453382,-99.0938264298
# 678296  19.391976  19.3919756809,-99.1519095001
# 527719  19.341553  19.3415526618,-99.1409598722
# 291883  19.418229   19.4182285503,-99.193926991

# %%
# We want only the mayors from Ciudad de Mexico
df = df[df['alcaldia_hechos'].isin (['ALVARO OBREGON','AZCAPOTZALCO','BENITO JUAREZ','COYOACAN','CUAJIMALPA DE MORELOS','CUAUHTEMOC','GUSTAVO A MADERO','IZTACALCO','IZTAPALAPA','LA MAGDALENA CONTRERAS','MIGUEL HIDALGO','MILPA ALTA','TLAHUAC','TLALPAN','VENUSTIANO CARRANZA','XOCHIMILCO'])]

# %%
# Convert the values to the right type
df['fecha_hechos'] = df['fecha_hechos'].astype('datetime64')
df['fecha_inicio'] = df['fecha_inicio'].astype('datetime64')

df['mes_hechos'] = pd.Categorical(df['mes_hechos'])
df['delito'] = pd.Categorical(df['delito'])
df['categoria_delito'] = pd.Categorical(df['categoria_delito'])
df['unidad_investigacion'] = pd.Categorical(df['unidad_investigacion'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fecha_inicio'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-d202722b564a> in <module>()
#       1 # Convert the values to the right type
#       2 df['fecha_hechos'] = df['fecha_hechos'].astype('datetime64')
# ----> 3 df['fecha_inicio'] = df['fecha_inicio'].astype('datetime64')
#       4
#       5 df['mes_hechos'] = pd.Categorical(df['mes_hechos'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'fecha_inicio'

# %%
# Summarise the data, including dates
df.describe(datetime_is_numeric=True)
# Out:
#                   id      ao_hechos      ao_inicio       longitud  \
# count  800207.000000  800021.000000  800207.000000  777531.000000
# mean   404440.724969    2017.233964    2017.385711     -99.137482
# std    233527.398708       1.412214       1.020460       0.058753
# min         0.000000    1906.000000    2016.000000     -99.342765
# 25%    202177.500000    2016.000000    2017.000000     -99.174906
# 50%    404476.000000    2017.000000    2017.000000     -99.142680
# 75%    606686.500000    2018.000000    2018.000000     -99.101421
# max    808870.000000    2019.000000    2019.000000     -98.946873
#
#              latitud
# count  777531.000000
# mean       19.388497
# std         0.069692
# min         9.486549
# 25%        19.342264
# 50%        19.391685
# 75%        19.437588
# max        19.582490

# %%
# How many crimes are recorded in this dataset? In which period?
print(f"There are {len(df)} crimes, from {df['fecha_inicio'].min()} to {df['fecha_inicio'].max()}")
# Out:
# There are 800207 crimes, from 2016-01-01 01:35:06 to 2019-06-30 23:56:29

# %%
# How many crimes were recorded by year?
df['ao_hechos'].value_counts()
#df['ao_hechos'].value_counts(ascending=True).plot(kind='bar')
# Out:
# 2018.0    246998
# 2017.0    223035
# 2016.0    192180
# 2019.0    112400
# 2015.0     15088
#            ...
# 1960.0         1
# 1977.0         1
# 1954.0         1
# 1968.0         1
# 1906.0         1
# Name: ao_hechos, Length: 66, dtype: int64

# %%
df.set_index('fecha_inicio',inplace=True)

# %%
df_count = df.groupby(df.index.year).size().reset_index(name='obs')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-2b81980e58c4> in <module>()
# ----> 1 df_count = df.groupby(df.index.year).size().reset_index(name='obs')
#
# AttributeError: 'Index' object has no attribute 'year'

# %%
df_count.plot.bar(title='Crimes per year',x='fecha_inicio',y='obs')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-1214e6d64a09> in <module>()
# ----> 1 df_count.plot.bar(title='Crimes per year',x='fecha_inicio',y='obs')
#
# NameError: name 'df_count' is not defined

# %%
# Show the top 5 crimes

# %%
# Calculate the accumulated rate of the top 5 crimes

# %%
# Which city has the most and the less crimes in the dataset?

# %%
# In each city, what are the top 3 subcities ("Colonias") with most crimes?

# %%
# Do you see a trend per month or day?
